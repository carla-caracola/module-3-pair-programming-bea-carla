# %%
import pandas as pd
import numpy as np

# %%
df_productos = pd.read_csv("../data/productos_corregido.csv", sep=";", index_col=0)

# %%
df_productos.head()
# Out:
#            Nombre_Producto          Categoría Precio  Origen  \
# ID
# A1        Pizza Margherita  Platos Preparados   8.99  Italia
# B2  Risotto de Champiñones  Platos Preparados   6.75  Italia
# C3                Tiramisú            Postres   5.49  Italia
# D4               Panettone         Repostería  10.99  Italia
# E5             Orecchiette    Productos Secos   4.29  Italia
#
#                                           Descripción
# ID
# A1  Clásica pizza italiana con tomate,mozzarella f...
# B2  Risotto cremoso con champiñones frescos,una de...
# C3  Postre clásico italiano con capas de bizcocho ...
# D4  Pan dulce navideño italiano con frutas confita...
# E5  Pequeñas pastas con forma de orecchiette ideal...

# %%
df_clientes = pd.read_csv("../data/clientes.csv", index_col=0)
df_clientes.head()
# Out:
#     first_name last_name                         email  gender  \
# id
# 1        Cheri  Dunsmore      cdunsmore0@instagram.com  Female
# 2         Hunt  Bartomeu         hbartomeu1@nsw.gov.au    Male
# 3   Michaeline   Paynton            mpaynton2@narod.ru  Female
# 4       Filmer    Eirwin            feirwin3@intel.com     NaN
# 5       Tanhya   Lubbock  tlubbock4@huffingtonpost.com  Female
#
#                            City Country                   Address
# id
# 1             Palma De Mallorca   Spain  076 Rockefeller Crossing
# 2                          Lugo   Spain        0046 Utah Junction
# 3                           NaN   Spain          0 Corry Crossing
# 4                          Leon   Spain       5 American Ash Road
# 5   Hospitalet De Llobregat, L'   Spain         9289 Merry Circle

# %%
df_ventas = pd.read_csv("../data/ventas.csv", index_col=0)
df_ventas.head()
# Out:
#            ID_Producto Fecha_Venta  Cantidad  Total
# ID_Cliente
# 723                 A1  2023-11-22         2  17.98
# 498                 C3  2023-11-21         1   5.49
# 121                 D4  2023-11-20         3  32.97
# 885                L12  2023-11-19         1   6.49
# 347                Q17  2023-11-18         2   7.98

# %%
lista_df = [df_productos, df_clientes, df_ventas]
for df in lista_df:
    df.info()
    print("________________________________")
    print(f"La cantidad de duplicados es: {df.duplicated().sum()}")
    print("________________________________")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, A1 to GG33
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre_Producto  33 non-null     object
#  1   Categoría        33 non-null     object
#  2   Precio           33 non-null     object
#  3   Origen           33 non-null     object
#  4   Descripción      32 non-null     object
# dtypes: object(5)
# memory usage: 1.5+ KB
# ________________________________
# La cantidad de duplicados es: 0
# ________________________________
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       973 non-null    object
#  3   gender      923 non-null    object
#  4   City        876 non-null    object
# ...

# %%
df_productos["Precio"] = df_productos["Precio"].replace("Italia", np.nan)
df_productos["Precio"].unique()
# Out:
# array(['8.99', '6.75', '5.49', '10.99', '4.29', '3.75', '9.25', '5.99',
#        '7.49', '4.89', nan, '3.99', '4.75', '5.25', '4.25', '2.49',
#        '9.99', '7.89', '5.75', '12.45', '8.75', '6.99', '9.45', '5.89'],
#       dtype=object)

# %%
df_productos["Precio"] = df_productos["Precio"].astype(float)
df_productos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 33 entries, A1 to GG33
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Nombre_Producto  33 non-null     object
#  1   Categoría        33 non-null     object
#  2   Precio           32 non-null     float64
#  3   Origen           33 non-null     object
#  4   Descripción      32 non-null     object
# dtypes: float64(1), object(4)
# memory usage: 2.6+ KB

# %%
df_clientes = df_clientes.fillna("Unkown")
df_clientes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, 1 to 1000
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   first_name  1000 non-null   object
#  1   last_name   1000 non-null   object
#  2   email       1000 non-null   object
#  3   gender      1000 non-null   object
#  4   City        1000 non-null   object
#  5   Country     1000 non-null   object
#  6   Address     1000 non-null   object
# dtypes: object(7)
# memory usage: 62.5+ KB

# %%
#df_ventas["Fecha"] = df_ventas["Fecha"].astype()
#df_ventas.info()

# %%
for df in lista_df:
    print("________________________________")
    print("________________________________")
    for colum in df:
        print(df[colum].unique())
        print("________________________________")
# Out:
# ________________________________
# ________________________________
# ['Pizza Margherita' 'Risotto de Champiñones' 'Tiramisú' 'Panettone'
#  'Orecchiette' 'Polenta Tradicional' 'Mozzarella di Bufala'
#  'Pesto Genovese' 'Lasagna Bolognesa' 'Arroz Arborio' 'Café Espresso,Café'
#  'Sardinas en Aceite de Oliva' 'Pesto Rosso' 'Gnocchi de Patata'
#  'Ravioli de Ricotta y Espinacas' 'Caponata' 'Pasta de Trigo'
#  'Salsa de Tomate Casera' 'Aceite de Oliva Virgen Extra' 'Queso Parmesano'
#  'Salami Toscano' 'Prosciutto di Parma' 'Gelato de Limón' 'Cannoli'
#  'Cacciatore' 'Calzone' 'Caponata di Melanzane' 'Cappelletti' 'Carbonara'
#  'Carciofi Ripieni' 'Casatiello' 'Cassata Siciliana' 'Ciceri e Tria']
# ________________________________
# ['Platos Preparados' 'Postres' 'Repostería' 'Productos Secos' 'Harinas'
#  'Productos Lácteos' 'Salsas' '6.49' 'Pescados en Conserva'
#  'Productos Congelados' 'Aceites' 'Embutidos' 'Helados' 'Dulces' 'Pizzas'
#  'Entrantes' 'Verduras']
# ...
